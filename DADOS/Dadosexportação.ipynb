# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseSergio414/Fontes_dados/blob/main/Dadosexporta%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trabalho de Projeto Integrador (API)

# %%
import pandas as pd

# %% [markdown]
# Now, I'll remove duplicate rows from the DataFrame and filter it based on your chosen SH4 codes. Please provide the list of SH4 codes you want to keep in the `selected_sh4_codes` variable.

# %%
data = {'coluna_1':[1.5,2.0,1.7,2.2,1.9],
        'coluna_2':[10.0,12.0,11.5,13.0,11.0],
        'coluna_3':[0,1,0,1,0],
        'coluna_4':[1,0,1,1,0],
        'coluna_5':[20.5,25.5,22.0,27.0,23.0]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    coluna_1  coluna_2  coluna_3  coluna_4  coluna_5
# 0       1.5      10.0         0         1      20.5
# 1       2.0      12.0         1         0      25.5
# 2       1.7      11.5         0         1      22.0
# 3       2.2      13.0         1         1      27.0
# 4       1.9      11.0         0         0      23.0

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/MyDrive/Data/COMEXSTAT/'

# %%
arquivo_1 = origem + 'EXP_2021_MUN.csv'
arquivo_2 = origem + 'EXP_2022_MUN.csv'
ncm = origem + 'NCM.csv'
pais = origem + 'PAIS.csv'
uf_mun =origem + 'UF_MUN.csv'
ncm_sh = origem + 'NCM_SH.csv'

# %%
exp21 = pd.read_csv(arquivo_1,low_memory=False,sep=';',encoding='UTF-8')
exp22 = pd.read_csv(arquivo_2,low_memory=False,sep=';',encoding='UTF-8')
expncm = pd.read_csv(ncm,low_memory=False,sep=';',encoding='latin1')
exppais = pd.read_csv(pais,low_memory=False,sep=';',encoding='latin1')
expufmun = pd.read_csv(uf_mun,low_memory=False,sep=';',encoding='latin1')
expsh = pd.read_csv(ncm_sh,low_memory=False,sep=';',encoding='latin1')

# %%
exp_final=pd.concat([exp21,exp22], ignore_index=True)
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2162653 entries, 0 to 2162652
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
# dtypes: int64(7), object(1)
# memory usage: 132.0+ MB

# %%
exp_final = exp_final.merge(expsh[['CO_SH4','NO_SH4_POR']],left_on='SH4', right_on='CO_SH4',how='left')

# %%
exp_final = exp_final.merge(exppais[['CO_PAIS','NO_PAIS']],on='CO_PAIS',how='left')

# %%
exp_final = exp_final.merge(expufmun[['CO_MUN_GEO','NO_MUN_MIN']],left_on='CO_MUN', right_on='CO_MUN_GEO',how='left')

# %%
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17167559 entries, 0 to 17167558
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
#  8   CO_SH4      int64
#  9   NO_SH4_POR  object
#  10  NO_PAIS     object
#  11  CO_MUN_GEO  int64
#  12  NO_MUN_MIN  object
# dtypes: int64(9), object(4)
# memory usage: 1.7+ GB

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 0    2021       3  3305      493        SP  3434401         966    7788
# 1    2021       3  3305      493        SP  3434401         966    7788
# 2    2021       3  3305      493        SP  3434401         966    7788
# 3    2021       3  3305      493        SP  3434401         966    7788
# 4    2021       7  8419      386        SP  3409502           1    1544
#
#    CO_SH4                                         NO_SH4_POR NO_PAIS  \
# 0    3305                              Preparações capilares  México
# 1    3305                              Preparações capilares  México
# 2    3305                              Preparações capilares  México
# 3    3305                              Preparações capilares  México
# 4    8419  Aparelhos e dispositivos, mesmo aquecidos elec...  Itália
#
#    CO_MUN_GEO NO_MUN_MIN
# 0     3434401     Osasco
# 1     3434401     Osasco
# 2     3434401     Osasco
# ...

# %%
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17167559 entries, 0 to 17167558
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
#  8   CO_SH4      int64
#  9   NO_SH4_POR  object
#  10  NO_PAIS     object
#  11  CO_MUN_GEO  int64
#  12  NO_MUN_MIN  object
# dtypes: int64(9), object(4)
# memory usage: 1.7+ GB

# %%
exp_final.drop_duplicates(inplace=True)
print("Duplicate rows removed.")
# Out:
# Duplicate rows removed.

# %% [markdown]
# Now, filter the DataFrame based on your chosen SH4 codes. Please provide the list of SH4 codes you want to keep in the `selected_sh4_codes` variable.

# %%
# Define the list of SH4 codes you want to keep
# Replace the list below with your desired SH4 codes
selected_sh4_codes = [7307,7318,8483,8487,8457,8458,8459,8461,8466,8207
    # Add your SH4 codes here, e.g., 1234, 5678
]

# Filter the DataFrame based on the selected SH4 codes
exp_final_filtered = exp_final[exp_final['SH4'].isin(selected_sh4_codes)].copy()

# Display information about the filtered DataFrame
exp_final_filtered.info()

# Display the first few rows of the filtered DataFrame
display(exp_final_filtered.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70978 entries, 272 to 17167497
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CO_ANO      70978 non-null  int64
#  1   CO_MES      70978 non-null  int64
#  2   SH4         70978 non-null  int64
#  3   CO_PAIS     70978 non-null  int64
#  4   SG_UF_MUN   70978 non-null  object
#  5   CO_MUN      70978 non-null  int64
#  6   KG_LIQUIDO  70978 non-null  int64
#  7   VL_FOB      70978 non-null  int64
#  8   CO_SH4      70978 non-null  int64
#  9   NO_SH4_POR  70978 non-null  object
#  10  NO_PAIS     70978 non-null  object
#  11  CO_MUN_GEO  70978 non-null  int64
#  12  NO_MUN_MIN  70978 non-null  object
# dtypes: int64(9), object(4)
# memory usage: 7.6+ MB
#      CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 272    2021       6  7318      245        SP  3456701         564    7871
# ...

# %%
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2162653 entries, 0 to 17167547
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
#  8   CO_SH4      int64
#  9   NO_SH4_POR  object
#  10  NO_PAIS     object
#  11  CO_MUN_GEO  int64
#  12  NO_MUN_MIN  object
# dtypes: int64(9), object(4)
# memory usage: 231.0+ MB

# %%
exp_final.head(5)
# Out:
#     CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 0     2021       3  3305      493        SP  3434401         966    7788
# 4     2021       7  8419      386        SP  3409502           1    1544
# 20    2021      12  8511       63        PR  4106902          73     907
# 27    2021       7  6204      586        SC  4202909          75    3942
# 52    2021       8  8708       63        SP  3440002        6949   29604
#
#     CO_SH4                                         NO_SH4_POR    NO_PAIS  \
# 0     3305                              Preparações capilares     México
# 4     8419  Aparelhos e dispositivos, mesmo aquecidos elec...     Itália
# 20    8511  Aparelhos e dispositivos elétricos de ignição ...  Argentina
# 27    6204  Fatos de saia-casaco, conjuntos, casacos, vest...   Paraguai
# 52    8708  Partes e acessórios dos veículos automóveis da...  Argentina
#
#     CO_MUN_GEO NO_MUN_MIN
# 0      3434401     Osasco
# 4      3409502   Campinas
# ...

# %%
exp_final.tail(5)
# Out:
#           CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  \
# 17167520    2022       9  2201      445        SP  3448500        1260
# 17167522    2022       7  9603      586        RS  4304804          24
# 17167529    2022       9  8527      239        PR  4120804         234
# 17167541    2022       1   203      767        PA  1506807          30
# 17167547    2022       1  8527       63        SP  3452403           7
#
#           VL_FOB  CO_SH4                                         NO_SH4_POR  \
# 17167520     328    2201  Águas, incluídas as águas minerais, naturais o...
# 17167522     350    9603  Vassouras e escovas, mesmo constituindo partes...
# 17167529   34731    8527  Aparelhos receptores para radiotelefonia, radi...
# 17167541     226     203  Carnes de animais da espécie suína, frescas, r...
# 17167547    2246    8527  Aparelhos receptores para radiotelefonia, radi...
#
#              NO_PAIS  CO_MUN_GEO      NO_MUN_MIN
# ...

# %%
coluna = 'NO_PAIS'
cp = exp_final[coluna].value_counts().sort_values(ascending=False)
print(f'total de operações {coluna}:')
print(cp)
# Out:
# total de operações NO_PAIS:
# NO_PAIS
# Estados Unidos                             149327
# Paraguai                                   144722
# Argentina                                  138913
# Uruguai                                    102627
# Chile                                       99728
#                                             ...
# Saara Ocidental                                 1
# Geórgia do Sul e Sandwich do Sul, Ilhas         1
# Território Britânico do Oceano Índico           1
# Santa Helena                                    1
# Groenlândia                                     1
# Name: count, Length: 247, dtype: int64

# %%
print(exp_final.columns)
# Out:
# Index(['CO_ANO', 'CO_MES', 'SH4', 'CO_PAIS', 'SG_UF_MUN', 'CO_MUN',
#        'KG_LIQUIDO', 'VL_FOB', 'CO_SH4', 'NO_SH4_POR', 'NO_PAIS', 'CO_MUN_GEO',
#        'NO_MUN_MIN'],
#       dtype='object')

# %%
exp_final.to_csv(origem+'exp_final.csv',index=False)
